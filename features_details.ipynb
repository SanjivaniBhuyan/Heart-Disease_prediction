# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
cols=['age','sex','chest_pain','resting_bp','cholestrol','fbs','resting_ecg','max_pulse','angina','oldpeak','slope','major_vessels','thal','target']
df =pd.read_csv("heart.csv",names =cols,header=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            1025 non-null   int64
#  1   sex            1025 non-null   int64
#  2   chest_pain     1025 non-null   int64
#  3   resting_bp     1025 non-null   int64
#  4   cholestrol     1025 non-null   int64
#  5   fbs            1025 non-null   int64
#  6   resting_ecg    1025 non-null   int64
#  7   max_pulse      1025 non-null   int64
#  8   angina         1025 non-null   int64
#  9   oldpeak        1025 non-null   float64
#  10  slope          1025 non-null   int64
#  11  major_vessels  1025 non-null   int64
#  12  thal           1025 non-null   int64
#  13  target         1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
for col in df.columns:
    print(col, df[col].unique())
# Out:
# age [52 53 70 61 62 58 55 46 54 71 43 34 51 50 60 67 45 63 42 44 56 57 59 64
#  65 41 66 38 49 48 29 37 47 68 76 40 39 77 69 35 74]
# sex [1 0]
# chest_pain [0 1 2 3]
# resting_bp [125 140 145 148 138 100 114 160 120 122 112 132 118 128 124 106 104 135
#  130 136 180 129 150 178 146 117 152 154 170 134 174 144 108 123 110 142
#  126 192 115  94 200 165 102 105 155 172 164 156 101]
# cholestrol [212 203 174 294 248 318 289 249 286 149 341 210 298 204 308 266 244 211
#  185 223 208 252 209 307 233 319 256 327 169 131 269 196 231 213 271 263
#  229 360 258 330 342 226 228 278 230 283 241 175 188 217 193 245 232 299
#  288 197 315 215 164 326 207 177 257 255 187 201 220 268 267 236 303 282
#  126 309 186 275 281 206 335 218 254 295 417 260 240 302 192 225 325 235
#  274 234 182 167 172 321 300 199 564 157 304 222 184 354 160 247 239 246
#  409 293 180 250 221 200 227 243 311 261 242 205 306 219 353 198 394 183
#  237 224 265 313 340 259 270 216 264 276 322 214 273 253 176 284 305 168
# ...

# %%
df.isnull().sum()
# Out:
# age              0
# sex              0
# chest_pain       0
# resting_bp       0
# cholestrol       0
# fbs              0
# resting_ecg      0
# max_pulse        0
# angina           0
# oldpeak          0
# slope            0
# major_vessels    0
# thal             0
# target           0
# dtype: int64

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(12,18))
p=sns.heatmap(df.corr(), vmin=1,vmax=1,cmap='YlGnBu',annot=True)
plt.title("Correlation among all the attributes ",fontsize =23)
# Out:
# Text(0.5, 1.0, 'Correlation among all the attributes ')

# %%
sns.pairplot(df, hue='target')

# %% [raw]
# Analysing attributes with respect to target values

# %%
plt.figure(figsize=(10,6))
p=sns.histplot(data =df, x='max_pulse' ,kde =True,hue ='target')
plt.xlabel("Maximum pulse",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.title("Maximum pulse wrt target", fontsize=23)
plt.show(p)

# %%
plt.figure(figsize=(10,6))
q=sns.histplot(data =df, x='cholestrol' ,kde =True,hue ='target')
plt.xlabel("cholestrol",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.title("cholestrol wrt target", fontsize=23)
plt.show(q)

# %%
plt.figure(figsize=(10,6))
r=sns.histplot(data =df, x='resting_ecg' ,kde =True,hue ='target')
plt.xlabel("resting_ecg",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.title("resting_ecg wrt target", fontsize=23)
plt.show(r)

# %%
plt.figure(figsize=(10,6))
s=sns.histplot(data =df, x='angina' ,kde =True,hue ='target')
plt.xlabel("angina",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.title("angina wrt target", fontsize=23)
plt.show(r)

# %%
plt.figure(figsize=(10,6))
t=sns.histplot(data =df, x='oldpeak' ,kde =True,hue ='target')
plt.xlabel("oldpeak",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.title("oldpeak wrt target", fontsize=23)
plt.show(r)

# %%
female = len(df[df['target'] == 1])
male = len(df[df['target']== 0])

# %%
plt.figure(figsize=(9,5))
p=sns.countplot(x="sex", data=df, hue='target',palette='bright')
plt.xlabel('Gender',fontsize=30)
plt.ylabel('Count', fontsize=30)
y=(female , male)
plt.title("Gender count based on heart disease", fontsize =33)
plt.show(p)

# %%
female = len(df[df['target'] == 1])
male = len(df[df['target']== 0])

# %%
plt.figure(figsize=(10,6))
u=sns.histplot(data =df, x='thal' ,kde =True,hue ='target')
plt.xlabel("thal",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.title("thal wrt target", fontsize=23)
plt.show(r)

# %%
plt.figure(figsize=(9,5))
p=sns.countplot(x="chest_pain", data=df, hue='target',palette='bright')
plt.xlabel('chest_pain',fontsize=30)
plt.ylabel('Count', fontsize=30)
plt.title("Chest_pain count based on heart disease", fontsize =33)
plt.show(p)

# %%
plt.figure(figsize=(9,5))
p=sns.countplot(x="slope", data=df, hue='target',palette='bright')
plt.xlabel('slope',fontsize=30)
plt.ylabel('Count', fontsize=30)
plt.title("Slope count based on heart disease", fontsize =33)
plt.show(p)

# %%
plt.figure(figsize=(9,5))

p=sns.countplot(x="age", data=df, hue='target',palette='bright')
plt.xlabel('age',fontsize=30)
plt.ylabel('Count', fontsize=30)
plt.title("Age count based on heart disease", fontsize =33)
plt.show(p)

# %%
plt.figure(figsize=(10,6))
s=sns.histplot(data =df, x='age' ,kde =True,hue ='target')

plt.xlabel("Age",fontsize=30)
plt.ylabel("Cholestrol",fontsize=30)
plt.title("Age wrt Cholestrol", fontsize=33)
plt.show(r)
